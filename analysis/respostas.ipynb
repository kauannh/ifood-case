# %%
# %sql
-- Qual a média de valor total (total\_amount) recebido em um mês
-- considerando todos os yellow táxis da frota?

SELECT
    date_format(date_trunc('MM', tpep_pickup_datetime), 'yyyy-MM') as tpep_pickup_month,
    AVG(total_amount) AS avg_total_amount
FROM ifood_case.trusted.ny_taxi_trip_yellow
WHERE total_amount > 0
  AND passenger_count > 0
  AND tpep_dropoff_datetime > tpep_pickup_datetime
-- FILTRO OPCIONAL PARA OBTER APENAS CORRIDAS DE JAN/2023 A MAI/2023
--AND tpep_pickup_datetime >= '2023-01-01' AND tpep_pickup_datetime < '2023-06-01'
GROUP BY date_format(date_trunc('MM', tpep_pickup_datetime), 'yyyy-MM')
ORDER BY 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tpep_pickup_month</th><th>avg_total_amount</th></tr></thead><tbody><tr><td>2001-01</td><td>56.276666666666664</td></tr><tr><td>2002-12</td><td>37.1875</td></tr><tr><td>2003-01</td><td>85.74</td></tr><tr><td>2008-12</td><td>48.009166666666665</td></tr><tr><td>2009-01</td><td>10.45</td></tr><tr><td>2014-11</td><td>52.38</td></tr><tr><td>2022-10</td><td>69.13545454545455</td></tr><tr><td>2022-12</td><td>26.3292</td></tr><tr><td>2023-01</td><td>27.463401396946345</td></tr><tr><td>2023-02</td><td>27.36984317650016</td></tr><tr><td>2023-03</td><td>28.28896749410417</td></tr><tr><td>2023-04</td><td>28.784269247371224</td></tr><tr><td>2023-05</td><td>29.45331736045793</td></tr><tr><td>2023-06</td><td>38.378750000000004</td></tr><tr><td>2023-07</td><td>20.71777777777778</td></tr><tr><td>2023-08</td><td>25.68</td></tr><tr><td>2023-09</td><td>12.96</td></tr></tbody></table></div>

# %%
# %sql
-- Qual a média de passageiros (passenger\_count) por cada hora do dia
-- que pegaram táxi no mês de maio considerando todos os táxis da frota?

WITH total_passengers AS (
    SELECT tpep_pickup_datetime AS pickup_datetime, tpep_dropoff_datetime as dropoff_datetime, passenger_count
    FROM ifood_case.trusted.ny_taxi_trip_yellow
    UNION ALL
    SELECT lpep_pickup_datetime AS pickup_datetime, lpep_dropoff_datetime as dropoff_datetime, passenger_count
    FROM ifood_case.trusted.ny_taxi_trip_green
)
SELECT
    date_format(pickup_datetime, 'HH') AS pickup_hour,
    AVG(passenger_count) AS avg_passenger_count
FROM total_passengers
WHERE pickup_datetime >= '2023-05-01'
  AND pickup_datetime <  '2023-06-01'
  and dropoff_datetime > pickup_datetime
  -- FILTRO PARA REMOVER CORRIDAS COM PASSENGER_COUNT NULL
  AND passenger_count > 0
GROUP BY date_format(pickup_datetime, 'HH')
ORDER BY 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_hour</th><th>avg_passenger_count</th></tr></thead><tbody><tr><td>00</td><td>1.4263078498519</td></tr><tr><td>01</td><td>1.434829674232942</td></tr><tr><td>02</td><td>1.4530734161295393</td></tr><tr><td>03</td><td>1.4483268109575913</td></tr><tr><td>04</td><td>1.4024886191198787</td></tr><tr><td>05</td><td>1.2837135278514589</td></tr><tr><td>06</td><td>1.2614292717236089</td></tr><tr><td>07</td><td>1.2809297121565564</td></tr><tr><td>08</td><td>1.2934777559268493</td></tr><tr><td>09</td><td>1.3106747924882112</td></tr><tr><td>10</td><td>1.3460646828563827</td></tr><tr><td>11</td><td>1.3610797865538207</td></tr><tr><td>12</td><td>1.3741410741831441</td></tr><tr><td>13</td><td>1.382673957101841</td></tr><tr><td>14</td><td>1.3875512803746919</td></tr><tr><td>15</td><td>1.3989981724696279</td></tr><tr><td>16</td><td>1.395745263724689</td></tr><tr><td>17</td><td>1.3870047200450353</td></tr><tr><td>18</td><td>1.3813128326434063</td></tr><tr><td>19</td><td>1.3902121697357885</td></tr><tr><td>20</td><td>1.39939998461499</td></tr><tr><td>21</td><td>1.4178790516976745</td></tr><tr><td>22</td><td>1.4262127984301756</td></tr><tr><td>23</td><td>1.4210191927725144</td></tr></tbody></table></div>
