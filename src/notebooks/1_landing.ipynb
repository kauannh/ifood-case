# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from ingestion.ny_taxi_trip_extractor import NyTaxiTripExtractor

trip_types = ["yellow", "green"]

for trip_type in trip_types:
    ny_taxi_trip_extractor = NyTaxiTripExtractor(
        dbutils=dbutils, trip_type=trip_type
    )
    ny_taxi_trip_extractor.extract()
