# %%
# %sql
-- COMANDOS PARA CRIACAO DO CATALOGO, VOLUME E SCHEMAS
CREATE CATALOG IF NOT EXISTS ifood_case;
CREATE VOLUME IF NOT EXISTS ifood_case.default.landing;
CREATE SCHEMA IF NOT EXISTS ifood_case.raw;
CREATE SCHEMA IF NOT EXISTS ifood_case.trusted;
