# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from ingestion.ny_taxi_trip_extractor import NyTaxiTripExtractor

TRIP_TYPES_TO_EXTRACT = ["yellow", "green"]
ny_taxi_trip_extractor = NyTaxiTripExtractor(dbutils=dbutils)
for trip_type in TRIP_TYPES_TO_EXTRACT:    
    ny_taxi_trip_extractor.extract(trip_type=trip_type)

print("Job finalizado, arquivos carregados na camada landing!")
